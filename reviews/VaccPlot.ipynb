# %%
import pandas as pd
import os

# %%
vac_df.YEAR.iloc[0]+1
# Out:
# 2009

# %%
years  = [2008, 2009, 2019, 2011, 2012, 2013, 2014, 2015, 2016, 2017,2018, 2019, 2020]
vac_df = pd.read_excel(os.path.join("..", "data", 'men_vacc.xlsx'))
vac_df = vac_df[vac_df['YEAR'].isin(years)]
vac_df
# Out:
#     YEAR MEN_ANY_REC=YES or MEN_ANY_SC=YES excluding conflicting responses  \
# 0   2008                                              0.339
# 1   2009                                              0.399
# 3   2011                                              0.458
# 4   2012                                              0.468
# 5   2013                                              0.488
# 7   2014                                               0.68
# 8   2015                                              0.708
# 9   2016                                              0.731
# 10  2017                                              0.749
# 11  2018                                               0.76
# 12  2019                                              0.778
# 13  2020                                              0.803
#
#    MEN_ANY_SC excluding NAN  P_NUMMEN=1  P_U13MEN ==UTD  \
# 0                     0.297       0.395           0.108
# ...
